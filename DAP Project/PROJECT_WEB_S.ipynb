# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.howzat.com/blog/cricket/virat-kohli-centuries-in-odi-test-t20"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="5U33RxbH4iqx5NcpMGpeg9U5aCUNP9Br91nkX0zP" name="csrf-token"/>
# <title>Virat Kohli Total Centuries | Know When Was Kohli's Last Century in All Format</title>
# <link href="https://d2cbroser6kssl.cloudfront.net/images/howzat/imgs/favicon.png" rel="icon" type="image/png"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" rel="stylesheet"/>
# <link href="https://www.howzat.com/blog//assets/front/css/font-awesome.min.css?v=44.12" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha256-eZrrJcwDc/3uDhsdt61sL2oOBY362qM3lon1gyExkL0=" rel="stylesheet"/>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>Virat Kohli Total Centuries | Know When Was Kohli's Last Century in All Format</title>

# %%
print(title.text)
# Out:
# Virat Kohli Total Centuries | Know When Was Kohli's Last Century in All Format

# %%
import pandas as pd

# %%
url="https://www.howzat.com/blog/cricket/virat-kohli-centuries-in-odi-test-t20"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="S43uywWjl2Ucj5igLYVNSI80gyZjUGCBx1OAbeNv" name="csrf-token"/>
# <title>Virat Kohli Total Centuries | Know When Was Kohli's Last Century in All Format</title>
# <link href="https://d2cbroser6kssl.cloudfront.net/images/howzat/imgs/favicon.png" rel="icon" type="image/png"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" rel="stylesheet"/>
# <link href="https://www.howzat.com/blog//assets/front/css/font-awesome.min.css?v=44.12" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha256-eZrrJcwDc/3uDhsdt61sL2oOBY362qM3lon1gyExkL0=" rel="stylesheet"/>
# ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table><colgroup><col style="width:16.99%;"/><col style="width:28.77%;"/><col style="width:14.24%;"/><col style="width:20%;"/><col style="width:20%;"/></colgroup><tbody><tr><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Format</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Last Century Date</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Score</strong></span></span></td><td><span style="background-color:transparent;c
# ...

# %%
Headings = table.find_all('tr')
print(Headings)
# Out:
# [<tr><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Format</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Last Century Date</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Score</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><
# ...

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['FormatLast Century DateScoreOpponentLocation', 'ODI15th November 2023117New ZealandMumbai', 'Test21st July, 2023121West IndiesTrinidad', 'T20I8th September, 2022122*AfghanistanDubai', 'Indian T20 League21st May, 2023101*GujaratBengaluru']

# %%
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [FormatLast Century DateScoreOpponentLocation, ODI15th November 2023117New ZealandMumbai, Test21st July, 2023121West IndiesTrinidad, T20I8th September, 2022122*AfghanistanDubai, Indian T20 League21st May, 2023101*GujaratBengaluru]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
# Out:
# [<tr><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Format</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Last Century Date</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><strong>Score</strong></span></span></td><td><span style="background-color:transparent;color:#222222;font-family:Arial;font-size:11pt;"><span style="font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap;"><
# ...

# %%
ind=0
for i in rows[1:6]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['ODI', '15th November 2023', '117', 'New Zealand', 'Mumbai']
# ['Test', '21st July, 2023', '121', 'West Indies', 'Trinidad']
# ['T20I', '8th September, 2022', '122*', 'Afghanistan', 'Dubai']
# ['Indian T20 League', '21st May, 2023', '101*', 'Gujarat', 'Bengaluru']

# %%
df
# Out:
#   FormatLast Century DateScoreOpponentLocation  \
# 0                                          ODI
# 1                                         Test
# 2                                         T20I
# 3                            Indian T20 League
#
#   ODI15th November 2023117New ZealandMumbai  \
# 0                        15th November 2023
# 1                           21st July, 2023
# 2                       8th September, 2022
# 3                            21st May, 2023
#
#   Test21st July, 2023121West IndiesTrinidad  \
# 0                                       117
# 1                                       121
# 2                                      122*
# 3                                      101*
#
#   T20I8th September, 2022122*AfghanistanDubai  \
# 0                                 New Zealand
# 1                                 West Indies
# 2                                 Afghanistan
# 3                                     Gujarat
#
# ...

# %%
df.to_csv("Virat Kohli last centuries.csv")
