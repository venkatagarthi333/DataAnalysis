# %%
import pandas as pd
a=['venkat','virat','kohli','jahnavi','lahari','sunny','dhanush']
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67     venkat
# 43      virat
# 44      kohli
# 89    jahnavi
# 34     lahari
# 45      sunny
# 23    dhanush
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#to read a dataset
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/DATASET/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_excel("/content/diabetcsv.xlsx",sheet_name=0)
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df.head())
print("tail")
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# tail
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df.describe())
# Out:
#             SEM1       SEM2      SEM3     Placed
# count  14.000000  17.000000  16.00000  17.000000
# mean    8.992857   9.000000   9.10000   0.588235
# std     0.929404   0.647109   1.05767   0.507300
# min     7.700000   8.000000   7.00000   0.000000
# 25%     8.000000   9.000000   9.20000   0.000000
# 50%     9.100000   9.100000   9.30000   1.000000
# 75%     9.800000   9.300000   9.90000   1.000000
# max     9.900000  10.000000  10.00000   1.000000

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df.describe().T)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df.shape)#get no.rows and columns
print(df.shape[0])#get the no.of rows only
print(df.shape[1])#get no.colummns only
# Out:
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
print(df.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(10)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   NaN   9.8  10.0     A       0
# 3    Mary        N   NaN   8.0   NaN     B       0
# 4    Jeen        K   NaN   9.1   9.9    A+       1
# 5     Raj        M   NaN   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1
# 8    Jess        K   NaN   9.1   9.9    A+       1
# 9  Rajini        M   NaN   9.1   9.3     A       0

# %%
#null
df2.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False   True  False  False  False   False
# 3  False     False   True  False   True  False   False
# 4  False     False   True  False  False  False   False
# 5  False     False   True  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
import pandas as pd

# %%
df.isnull().tail(7)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
#null()
print(df2.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
#extracting a column
print(df.columns)
print(df[['Names']])
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')
#      Names
# 0      Joe
# 1   Rajesh
# 2   Kissan
# 3     Mary
# 4     Jeen
# 5      Raj
# 6   Hassan
# 7     Mari
# 8     Jess
# 9   Rajini
# 10   Kiran
# 11    Maya
# 12   Jolin
# 13  Rajesh
# 14    Riya
# 15    Sana
# 16    Mark

# %%
print(df[df.index==1])

print(df[df.index.isin(range(2,5))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
df.loc[2:5,'SEM1']=None
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2.loc[[10,2,7]]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 7     Mari        N   7.7   8.0   7.1     B       1

# %%
df2.loc[10:15,['Names','Grade']]
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df2.iloc[10:14, :3]#row and column
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df2.loc[:7,['Names']]
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan
# 7    Mari

# %%
df.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
df[df.Grade=='A+']
df[df.SEM2==10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df.loc[df['SEM1']>=9.8,['Initials','Names']]
df3=df2.copy()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#to remove null value rows
print(df3)
df3.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0
# ...

# %%
df3.dropna(inplace=True,axis=1)#inplace says not to reflect changes in the df
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3=df.copy()
df3.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=df3['SEM1'].mean()
df3=df3.fillna(mv)
print(df3)
# Out:
#      Names Initials  SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K  9.80  10.0   9.90    A+       1
# 1   Rajesh        M  8.90   9.1   9.30     A       1
# 2   Kissan        V  8.96   9.8  10.00     A       0
# 3     Mary        N  8.96   8.0   8.96     B       0
# 4     Jeen        K  8.96   9.1   9.90    A+       1
# 5      Raj        M  8.96   9.1   9.30     A       1
# 6   Hassan        V  9.90   9.0   9.20     A       1
# 7     Mari        N  7.70   8.0   7.10     B       1
# 8     Jess        K  8.96   9.1   9.90    A+       1
# 9   Rajini        M  8.96   9.1   9.30     A       0
# 10   Kiran        V  8.96   9.3   9.20     A       0
# 11    Maya        N  7.70   8.0   7.10     B       0
# 12   Jolin        K  9.80   9.1   9.90    A+       1
# 13  Rajesh        M  8.90   9.1   9.30     A       1
# 14    Riya        M  9.30   9.9  10.00     A       1
# 15    Sana        V  9.90   9.3   9.20     A       0
# 16    Mark        N  7.70   8.0   7.00     B       0

# %%
#used to drop duplicate values
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/DATASET/grades_withnulls.csv")
df=df.drop_duplicates()
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#used to rename colunmns
df.rename(columns={'Grade':'GPA'},inplace=True)
df.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   NaN   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
#used to rename all the columns at a time without rename ()
df.columns=['Student_name','Mr/Ms','1st sem','2nd sem','3rd sem','F outcome','placed']
df.head()
# Out:
#   Student_name Mr/Ms  1st sem  2nd sem  3rd sem F outcome  placed
# 0          Joe     K      9.8     10.0      9.9        A+       1
# 1       Rajesh     M      8.9      9.1      9.3         A       1
# 2       Kissan     V      9.9      9.8     10.0         A       0
# 3         Mary     N      7.7      8.0      NaN         B       0
# 4         Jeen     K      9.8      9.1      9.9        A+       1

# %%
#used to add a new column
df['avg score']=(df['1st sem']+df['2nd sem']+df['3rd sem'])/3
df.head()
df['avg score']=(df['1st sem'])
df.head()df['avg score']=(df['1st sem'])
df.head()
# Out:
#   Student_name Mr/Ms  1st sem  2nd sem  3rd sem F outcome  placed  avg score
# 0          Joe     K      9.8     10.0      9.9        A+       1        9.9
# 1       Rajesh     M      8.9      9.1      9.3         A       1        9.1
# 2       Kissan     V      9.9      9.8     10.0         A       0        9.9
# 3         Mary     N      7.7      8.0      NaN         B       0        NaN
# 4         Jeen     K      9.8      9.1      9.9        A+       1        9.6

# %%
df.groupby('Placed').min()
# Out:
#          Names Initials  SEM1  SEM2  SEM3 Grade
# Placed
# 0        Kiran        M   7.7   8.0   7.0     A
# 1       Hassan        K   7.7   8.0   7.1     A

# %%
df[['SEM1','SEM2','SEM3']].plot.line()
# Out:
# <Axes: >

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
